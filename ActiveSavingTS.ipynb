# %%
from pandas import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
dates = [Timestamp('1984-12-31'), Timestamp('1989-12-31'), Timestamp('1994-12-31'), Timestamp('1999-12-31')
        , Timestamp('2001-12-31'), Timestamp('2003-12-31'), Timestamp('2005-12-31'), Timestamp('2007-12-31')
        , Timestamp('2009-12-31'), Timestamp('2011-12-31'), Timestamp('2013-12-31')]

data = read_csv('a_all.txt', '\t')
#data
df = DataFrame(data)
#df = pd.DataFrame(data, columns=['impWealthWE84', 'impWealthWE89', 'impWealthWE94', 'impWealthWE99',
#                                              'impWealthWE01', 'impWealthWE03', 'impWealthWE05', 'impWealthWE07',
#                                               'impWealthWE09', 'impWealthWE11', 'impWealthWE13'], index=dates )
print df[0:1]
#del df['uniqueID']
#df_test = df.transpose()
#df_test[1:2]
# Out:
#    uniqueID  impWealthWE84  impWealthWE89  impWealthWE94  impWealthWE99  \
# 6     47170           8015          38300          84870         308800
#
#    impWealthWE01  impWealthWE03  impWealthWE05  impWealthWE07  impWealthWE09  \
# 6         244000         221050         601300         171600         500800
#
#    impWealthWE11  impWealthWE13
# 6         978000         736500

# %%
ts = Series(df['impWealthWE01'])
ts.plot()

# %%
for i in range(5):
    plt.plot(np.array(data)[i])
